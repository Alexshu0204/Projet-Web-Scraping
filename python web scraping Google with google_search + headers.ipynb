# %%
from googlesearch import search
import requests
from bs4 import BeautifulSoup
import time
import random
from datetime import datetime
from fake_useragent import UserAgent
import sys
import threading

def generate_headers():
    ua = UserAgent()
    headers = {
        'User-Agent': ua.random,
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
    }
    return headers

def animate_loading(start_time, stop_event):
    while not stop_event.is_set():
        elapsed_time = int(time.time() - start_time)
        minutes, seconds = divmod(elapsed_time, 60)
        sys.stdout.write(f"\rScraping des résultats de recherche Google en cours. Veuillez patienter... Temps écoulé: {minutes} minutes et {seconds} secondes")
        sys.stdout.flush()
        time.sleep(1)

def fetch_title_and_snippet(url, headers):
    try:
        response = requests.get(url, headers=headers)
        response.encoding = response.apparent_encoding  # Utiliser l'encodage apparent
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Essayer de trouver le titre
        title = soup.title.string if soup.title else "N/A"
        
        # Essayer de trouver un extrait (snippet)
        snippet = " ".join(p.get_text() for p in soup.find_all('p')[:2])  # Prendre les deux premiers paragraphes
        
        return title, snippet
    except Exception as e:
        return "N/A", "N/A"

def google_search(query, max_results=10, max_duration=900):
    results = []
    try:
        start_time = time.time()
        stop_event = threading.Event()
        loading_thread = threading.Thread(target=animate_loading, args=(start_time, stop_event))
        loading_thread.start()

        # Limiter manuellement le nombre de résultats
        for i, url in enumerate(search(query)):
            if i >= max_results or (time.time() - start_time) >= max_duration:
                break
            headers = generate_headers()
            title, snippet = fetch_title_and_snippet(url, headers)
            site_name = url.split('/')[2] if '//' in url else url.split('/')[0]
            date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            results.append({'title': title, 'link': url, 'snippet': snippet, 'site_name': site_name, 'date': date})
            time.sleep(random.uniform(7, 11))  # Temps de pause pour chaque requête

        if (time.time() - start_time) >= max_duration:
            print("\nErreur : Le délai d'attente a été dépassé.")
            print("\nLes résultats récupérés : ")

        stop_event.set()
        loading_thread.join()  # Attendre que l'animation se termine

    except Exception as e:
        stop_event.set()
        loading_thread.join()
        print(f"\nErreur lors de la recherche Google : {e}")

    return results

if __name__ == "__main__":
    query = input('Rechercher sur le web : ')
    results = google_search(query, max_results=10, max_duration=900)  

    if results:
        print("\nRésultats de recherche Google pour : " + '"' + query + '"')

        #for result in results:
        for i, result in enumerate(results, 1):
            print(f"Résultat Google {i}:")
            print(f"Title: {result['title']}")
            print(f"Link: {result['link']}")
            print(f"Snippet: {result['snippet']}")
            print(f"Site Name: {result['site_name']}")
            print(f"Date: {result['date']}\n")

    print("FIN")
# Out:
# Rechercher sur le web : langage de programmation les plus utilisés dans le monde professionnel en 2024
# Scraping des résultats de recherche Google en cours. Veuillez patienter... Temps écoulé: 2 minutes et 31 secondes
# Résultats de recherche Google pour : "langage de programmation les plus utilisés dans le monde professionnel en 2024"
# Résultat Google 1:
# Title: Top 10 des langages de programmation en 2024 | Les actualités du Freelance
# Link: https://www.freelance-informatique.fr/actualites/langage-programmation-2024
# Snippet: Premiers outils du développeur, les langages de programmation sont le fondement de tous les systèmes informatiques et interfaces web. Leur connaissance est un véritable atout sur le marché de l’emploi, pour les programmeurs, mais aussi pour l’ensemble des professionnels du numérique. Il existe de très nombreux langages de programmation, de typologies variées. Il est utile de maîtriser les plus populaires, pour rester compétitif dans le monde professionnel et concevoir des interfaces maintenables.
# Site Name: www.freelance-informatique.fr
# Date: 2024-09-18 16:53:14
#
# Résultat Google 2:
# Title: Top 10 Langages de Programmation 2024 pour Carrière IT
# Link: https://www.admissions.fr/blog/actualite/apprendre-langages-programmation-incontournables/
# Snippet: Vous êtes un professionnel indépendant à la recherche d’opportunités de carrière ? Vous tenir à jour avec les langages de programmation les plus demandés fait partie de votre quotidien ? Que vous soyez un développeur expérimenté ou un novice prêt à plonger dans l’univers du code, vous vous devez de connaître les langages de programmation qui domineront en 2024. De l’intelligence artificielle aux applications mobiles, en passant par le développement web et les systèmes embarqués, chaque domaine du code est porteur de son propre langage, qu’il ne tient qu’à vous de maîtriser. Alors, prenez une longueur d’avance ! Découvrez dès maintenant le top 10 des langages de programmation en 2024. Avant de plonger dans le vif du sujet avec notre top 10 des langages de programmation, apprenez à reconnaître les métiers de l’IT pour lesquels ces compétences jouent le rôle central :
# Site Name: www.admissions.fr
# Date: 2024-09-18 16:53:26
#
# Résultat Google 3:
# Title: Carrière - Les meilleurs langages de programmation pour 2024 | Tekkit
# Link: https://tekkit.io/actu/carriere/les-langages-de-programmation-incontournables-pour-2024
# Snippet: On en parlait il y a quelques mois, on va voir l'évolution en 2024 des langages de programmation ! Est-ce que les cadors Python, Java, JavaScript, C# et PHP dominent toujours le secteur ? Que ce soit pour le développement web, la création de logiciels ou encore la cybersécurité, ces langages sont incontournables. Alors, quels sont les meilleurs langages de programmation pour booster votre carrière en 2024 ? Poursuivez votre lecture pour le découvrir.
# Site Name: tekkit.io
# Date: 2024-09-18 16:53:40
#
# Résultat Google 4:
# Title: Les 10 langages de programmation les plus utilisés en 2024
# Link: https://talks.freelancerepublik.com/10-langages-programmation-utiliser-2024/
# Snippet: Stratégies clés pour gérer les risques de projet Comment gérer facilement sa comptabilité en freelance ?
# Site Name: talks.freelancerepublik.com
# Date: 2024-09-18 16:53:52
#
# Résultat Google 5:
# Title: Quels sont les langages de programmation les plus utilisés en 2024
# Link: https://www.fed-group.ca/fed-it/conseils/langages-informatiques
# Snippet: Aujourd’hui, les langages informatiques sont véritablement innombrables. Aujourd’hui, les langages informatiques sont véritablement innombrables.
# Site Name: www.fed-group.ca
# Date: 2024-09-18 16:54:05
#
# Résultat Google 6:
# Title: Les 20 langages de programmation Ã  apprendre en 2024
# Link: https://welovedevs.com/fr/articles/les-20-langages-de-programmation-a-apprendre-en-2024/
# Snippet: La vie des informaticiens consiste Ã  apprendre diffÃ©rents langages de programmation et technologies. Et si certains sont des valeurs sÃ»res comme lâ€™or ou le dollar, dâ€™autres sont volatiles comme lâ€™Ethereum. Au delÃ  dâ€™apprendre un langage parce quâ€™il nous plait, câ€™est important de savoir si on va trouver du travail avec. Cet article sâ€™adresse Ã©galement aux recruteurâ€¢ses qui rÃ©digent leurs annonces. Les opÃ©rationnels vous ont balancÃ© une liste de mot clef pour votre GEPP ? Difficile dâ€™en faire une annonce ou un plan de formation ? Pas de soucis, on vous explique tout.
# Site Name: welovedevs.com
# Date: 2024-09-18 16:54:24
#
# Résultat Google 7:
# Title: Les 8 langages de programmation les plus utilisÃ©s en 2024 - Codeur Blog
# Link: https://www.codeur.com/blog/top-langages-de-programmation/
# Snippet: Les meilleurs dÃ©veloppeurs sont sur Codeur.com Sur Codeur.com, trouvez rapidement un freelance pour rÃ©aliser votre projet Langages. Voir les dÃ©veloppeurs disponibles
#
# Site Name: www.codeur.com
# Date: 2024-09-18 16:54:39
#
# Résultat Google 8:
# Title: Meilleurs langages de programmation à choisir en 2024 | Systèmes Zuci
# Link: https://www.zucisystems.com/be/blog/meilleurs-langages-de-programmation-en-2022-a-choisir-pour-votre-prochain-projet/
# Snippet: Temps de lecture : 1 Minutes Loves getting creative with mundane topics in addition to geeking out over books and movies.
# Site Name: www.zucisystems.com
# Date: 2024-09-18 16:54:52
#
# Résultat Google 9:
# Title: Tainix - Les langages de programmation incontournables en 2024
# Link: https://tainix.fr/conseil-formation-et-carriere/les-langages-de-programmation-incontournables-en-2024
# Snippet: T: / Formation et Carrière Découvres les langages de programmation clés à apprendre en 2024, peu importe ta spécialité.
# Site Name: tainix.fr
# Date: 2024-09-18 16:55:07
#
# Résultat Google 10:
# Title: Quel langage de programmation choisir en 2024
# Link: https://www.grandeecolenumerique.fr/actualites/quel-langage-de-programmation-choisir
# Snippet: Vous souhaitez vous former au numérique et au développement en particulier mais vous ne savez pas quel langage de programmation apprendre ? La GEN vous aide à y voir plus clair. Le développeur est un profil très recherché en entreprise : il est essentiel afin de concevoir un site web, une application ou un logiciel. Vous souhaitez vous former à ce métier phare de la Tech ?
# Site Name: www.grandeecolenumerique.fr
# Date: 2024-09-18 16:55:17
#
# FIN
